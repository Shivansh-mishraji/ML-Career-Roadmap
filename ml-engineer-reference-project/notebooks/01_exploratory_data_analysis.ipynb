# %% [markdown]
# # Exploratory Data Analysis (EDA) - Customer Churn
#
# In a real Machine Learning Engineering workflow, Jupyter Notebooks are primarily used for **exploration and experimentation**, NOT for production code.
#
# Once you figure out the preprocessing logic here, you move it into a robust Python script (like `src/preprocessing.py`) using Scikit-Learn Pipelines.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure the data exists first by running python src/data_ingestion.py
df = pd.read_csv('../data/raw/churn_data.csv')
df.head()

# %%
df.info()

# %% [markdown]
# ## Next Steps
# 1. Analyze correlations.
# 2. Identify missing values.
# 3. Check class imbalance for the `Churn` target.
# 4. Decide on feature engineering strategies.
#
# > **ML Engineer Tip:** Don't write 50 cells of cleaning data here and leave it. Write the cleaning logic into a `scikit-learn` Pipeline in the `src/` directory!
